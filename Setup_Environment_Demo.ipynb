# %% [markdown]
# <a href="https://colab.research.google.com/github/1320123015-hub/1320123015-data-mining/blob/main/Setup_Environment_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/1320123015-hub/1320123015-data-mining.git
# Out:
# fatal: destination path '1320123015-data-mining' already exists and is not an empty directory.

# %%
print("Hello, Data Mining!")
import pandas as pd
print("Versi Pandas yang terinstall:", pd.__version__)
# Out:
# Hello, Data Mining!
# Versi Pandas yang terinstall: 2.2.2
